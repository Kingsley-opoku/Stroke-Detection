# %%
# Loading the required libraries for the exploratory analysis
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import plotly.express as px

sns.set_context('paper')
# %matplotlib inline

# %%
# Loading and reading the data into a dataframe
df=pd.read_csv('E:/Datasets/capstone/healthcare-dataset-stroke-data.csv', index_col='id')

df.head()
# Out:
#        gender   age  hypertension  heart_disease ever_married      work_type  \
# id
# 9046     Male  67.0             0              1          Yes        Private
# 51676  Female  61.0             0              0          Yes  Self-employed
# 31112    Male  80.0             0              1          Yes        Private
# 60182  Female  49.0             0              0          Yes        Private
# 1665   Female  79.0             1              0          Yes  Self-employed
#
#       Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# id
# 9046           Urban             228.69  36.6  formerly smoked       1
# 51676          Rural             202.21   NaN     never smoked       1
# 31112          Rural             105.92  32.5     never smoked       1
# 60182          Urban             171.23  34.4           smokes       1
# 1665           Rural             174.12  24.0     never smoked       1

# %%
## shape of the data set

df.shape
# Out:
# (5110, 11)

# %%
df.columns.values
# Out:
# array(['gender', 'age', 'hypertension', 'heart_disease', 'ever_married',
#        'work_type', 'Residence_type', 'avg_glucose_level', 'bmi',
#        'smoking_status', 'stroke'], dtype=object)

# %%
## checking for missing data

df.isnull().sum()
# Out:
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %% [markdown]
# Since the missing value for the column 'bmi' is only 201 for the entire instances of the data. I will explore some methods to deal with the missing values the data.

# %%
## displaying the statistics for the numerical data 

df.describe()
# Out:
#                age  hypertension  heart_disease  avg_glucose_level  \
# count  5110.000000   5110.000000    5110.000000        5110.000000
# mean     43.226614      0.097456       0.054012         106.147677
# std      22.612647      0.296607       0.226063          45.283560
# min       0.080000      0.000000       0.000000          55.120000
# 25%      25.000000      0.000000       0.000000          77.245000
# 50%      45.000000      0.000000       0.000000          91.885000
# 75%      61.000000      0.000000       0.000000         114.090000
# max      82.000000      1.000000       1.000000         271.740000
#
#                bmi       stroke
# count  4909.000000  5110.000000
# mean     28.893237     0.048728
# std       7.854067     0.215320
# min      10.300000     0.000000
# 25%      23.500000     0.000000
# 50%      28.100000     0.000000
# 75%      33.100000     0.000000
# max      97.600000     1.000000

# %% [markdown]
# ## Graph for the numerical data

# %%
## Select columns with numeric data type

num_columns= list(df.select_dtypes(exclude='object'))
# Out:
# ['age', 'hypertension', 'heart_disease', 'avg_glucose_level', 'bmi', 'stroke']

# %%
fig = px.bar(df, x="gender", y="stroke", color="smoking_status", barmode="group")
fig.show()

# %%
sns.barplot(x='stroke', y='gender', hue="smoking_status", 
            data=df
    
)
# Out:
# <AxesSubplot:xlabel='stroke', ylabel='gender'>
